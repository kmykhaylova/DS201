# %% [markdown]
# ### Read the following instructions carefully.

# %% [markdown]
# 1. There are 5 problems in this test, and each is worth 12 points. There is also a bonus problem that is worth 10 points.
#
# 2. Collaborating is not allowed in this Exam. Piazza common forum will be in a radio silence during this Exam. You should not share your code in the piazza or anywhere, either. If you need to ask me something, make it a private post. I will be running plagiarism software to check all the submitted solutions. Any academic misconduct will be reported to the dean of students office immediately.
#
# 3. You can use notes, help files, posted lab and HWs solutions, and the internet to get help with the Exam.
#
# 4. Each problem and parts of these problems should be answered with codes and written analysis. Missing one or more of these codes and analysis is considered to be an incomplete solution.
#
# 5. When you solve exam problems, I want you to clean up the final submission file. For example, do not show the whole data if it is not asked. Do not print unnecessary output. Clearly label the solutions and write solutions right underneath the problem.
#
# 6. Submit the exam 1 part 2 in Canvas by following the link in canvas. Both files: html and ipynb are required for your exam 1 solution to be graded.

# %% [markdown]
# This exam uses diabetes data. Download the data from Canvas and read more details about this dataset in the following link.
# https://data.world/data-society/pima-indians-diabetes-database

# %% [markdown]
# ### Problem 1
# Upload the diabetes data, check and remove the null values,  check and change the data types (if needed) to ensure that variables are labeled correctly. Report the dimensions of the data and use the describe function to display various facts about the data. Finally, find mean, median, mode, range, standard deviation, and mean absolute deviation of all the numerical variables.
# Using specific examples from the summary statistics that you find, write a paragraph that explains what we have learned about the data.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# This data is 2 dimensional.

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
data.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
data.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %%
range = data.max() - data.min()
range
# Out:
# Pregnancies                  17.000
# Glucose                     199.000
# BloodPressure               122.000
# SkinThickness                99.000
# Insulin                     846.000
# BMI                          67.100
# DiabetesPedigreeFunction      2.342
# Age                          60.000
# Outcome                       1.000
# dtype: float64

# %%
data.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
data.mad()
# Out:
# Pregnancies                  2.771620
# Glucose                     25.181793
# BloodPressure               12.639425
# SkinThickness               13.659627
# Insulin                     84.505079
# BMI                          5.842270
# DiabetesPedigreeFunction     0.247309
# Age                          9.586405
# Outcome                      0.454373
# dtype: float64

# %% [markdown]
# From these statistics that we found some specific examples that describe the data are: from the mean data, it can be interpreted that the values for GLucose is much higher than the values for Insulin; the median tells us which value is located in the middle of the data set, like the middle value for pregnancies is 3; the mode tells us which values appear most often in each variable, like age 22 appears the most often; the range tells us tells us the difference between the largest and the smallest value, so we can interpret that the difference between the max and the min value of BMI is 67 and the difference between the max and min value of DPF is 2.342; we interpret the standard deviation as a value that shows variability in each variable, like blood pressure, which is 19.35, has more variability than skin thickness, which is 15.95; the mean absolute deviation measures the average distance between a data point and the mean of a variable, like the average distance between a value of Insulin and its mean is 84.5.

# %% [markdown]
# ###  Problem 2
# The Glucose variable lists all the Pima Indian women's glucose in the data set after 2 hours of the glucose tolerance test. Suppose a prediabetic person's blood glucose ranges between 140 and 199 mg/dl (both included). Also, anybody who has a BMI of more than 30 is obese. Is there anybody who is prediabetic, obese, and did not have diabetes? Filter the diabetes data using these conditions, and display the data as a data frame after resetting the index. How many Pima Indian prediabetic women who were obese did not have diabetes? Explain in a paragraph why do you think these women do not have diabetes?

# %%
locate = data.loc[(data["Glucose"] >= 140) & (data["Glucose"] <= 199) & (data["BMI"] > 30) & (data["Outcome"] == 0)]
locate.reset_index()
# Out:
#     index  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      40            3      180             64             25       70  34.0
# 1      54            7      150             66             42      342  34.7
# 2      58            0      146             82              0        0  40.5
# 3      95            6      144             72             27      228  33.9
# 4     144            4      154             62             31      284  32.8
# 5     148            5      147             78              0        0  33.7
# 6     153            1      153             82             42      485  40.6
# 7     166            3      148             66             25        0  32.5
# 8     178            5      143             78              0        0  45.0
# 9     211            0      147             85             54        0  42.8
# 10    212            7      179             95             31        0  34.2
# ...

# %% [markdown]
# Assuming that Outcome 0 is a female that does not have diabetes, there are 36 women who are obese who do not have diabetes.

# %% [markdown]
# ### Problem 3
#  Let's define a new variable called Weight as follows: underweight if  BMI $<$ 18.5;
# normalweight if  18.5 $\leq $ BMI $<$ 25; overweight if  25 $\leq $ BMI $<$ 30; and
# obese if  BMI $\geq 30$. Define another variable called Age_category with the following rule: Millenials if $Age\leq 35$; GenX if $35< Age\leq 50$; Boomer if $50< Age\leq 70$; and Senior if $Age> 50$. Report the number of women in each of the 4 weight categories.  Report the number of women in each of the 4 age categories.  Using the groupby function or pivot tables, provide at least two tables that summarize the data in a meaningful way.  Explain in a few sentences what your tables tell us about the data.

# %%
data['Weight'] = 'underweight'
data['Weight'].loc[data['BMI'] < 18.5] = 'underweight'
data['Weight'].loc[(data["BMI"] < 25) & (data["BMI"] >= 18.5)] = 'normalweight'
data['Weight'].loc[(data["BMI"] < 30) & (data["BMI"] >= 25)] = 'overweight'
data['Weight'].loc[(data["BMI"] > 30)] = 'obese'

# %%
data['Age_category'] = ''
data['Age_category'].loc[data['Age'] <= 35] = 'Millenial'
data['Age_category'].loc[(data["Age"] <= 50) & (data["Age"] > 35)] = 'GenX'
data['Age_category'].loc[(data["Age"] <= 70) & (data["Age"] > 50)] = 'Boomer'
data['Age_category'].loc[data['Age'] > 50] = 'Senior'

# %%
pd.pivot_table(data, values=)

# %% [markdown]
# ### Problem 4
# Plot the following with appropriate labels, titles, legends, and different colors for different plots.
# Bar graph (vertical or horizontal) of the Weight variable and Age_category variable.
# Histogram (with 10 bins) of the BMI and BloodPressure variable.
# Scatter plot of Age vs. BloodPressure, and Age vs. BMI ( Age in x-axis for both).
# Finally, make at least one observation from each of the plots.

# %%
plt.bar(x=data['Weight'], height=data['Age_category'])
plt.title("Weight Categories by Age")
plt.xlabel("Weight")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.hist(data['BMI'], bins=10)
plt.title("BMI occurences")
plt.xlabel("BMI")
# Out:
# Text(0.5, 0, 'BMI')

# %%
plt.hist(data['BloodPressure'], bins=10)
plt.title("Blood Pressure")
plt.xlabel("Blood pressure")
# Out:
# Text(0.5, 0, 'Blood pressure')

# %%
plt.scatter(x=data['Age'], y=data['BloodPressure'])
plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
# Out:
# Text(0, 0.5, 'Blood Pressure')

# %%
plt.scatter(x=data['Age'], y=data['BMI'])
plt.title("Age vs BMI")
plt.xlabel("Age")
plt.ylabel("BMI")
# Out:
# Text(0, 0.5, 'BMI')

# %% [markdown]
# ### Problem 5
# Recall the definition of outliers we used on problem 4 of Lab 3.  According to this definition, find the number of outliers for each numerical variable in the dataset.  Make a boxplot of the variables in one plot. Plot a heatmap plot of the correlations with the correlation coefficient in each box. Make sure to add axis labels, titles and legends in the plots. Finally, write a paragraph commenting on outliers, boxplots, and the heatmap.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

# %%
((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()
# Out:
# <ipython-input-205-75cc8fe15534>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()
# <ipython-input-205-75cc8fe15534>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()
# Age                          9
# Age_category                 0
# BMI                         19
# BloodPressure               45
# DiabetesPedigreeFunction    29
# Glucose                      5
# Insulin                     34
# Outcome                      0
# Pregnancies                  4
# SkinThickness                1
# ...

# %% [markdown]
# #### Problem 6 (Bonus, Optional, 10 points)
# A  new $\geq 40$ year-old obese Pima Indian Women named Chenoa has the data as follows: Chenoa had 6 or more pregnancies, has a glucose reading of 140 or more, and has hypertension (Bloodpressure > 80). What is the probability that Chenoa has diabetes?

# %%
locate = data.loc[(data['Age'] >= 40) & (data['Pregnancies'] >= 6) & (data['Glucose'] >= 140) & 
                  (data['BloodPressure'] > 80) & (data['Outcome'] == 1)]
locate
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 22             7      196             90              0        0  39.8
# 24            11      143             94             33      146  36.6
# 43             9      171            110             24      240  45.4
# 53             8      176             90             34      300  33.7
# 152            9      156             86             28      155  34.3
# 209            7      184             84             33        0  35.5
# 236            7      181             84             21      192  35.9
# 245            9      184             85             15        0  30.0
# 283            7      161             86              0        0  30.4
# 323           13      152             90             33       29  26.8
# 339            7      178             84              0        0  39.9
# 355            9      165             88              0        0  30.4
# ...

# %%
locate1 = data.loc[(data['Age'] >= 40) & (data['Pregnancies'] >= 6) & (data['Glucose'] >= 140) & 
                  (data['BloodPressure'] > 80)]
locate1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 22             7      196             90              0        0  39.8
# 24            11      143             94             33      146  36.6
# 28            13      145             82             19      110  22.2
# 43             9      171            110             24      240  45.4
# 53             8      176             90             34      300  33.7
# 152            9      156             86             28      155  34.3
# 209            7      184             84             33        0  35.5
# 212            7      179             95             31        0  34.2
# 236            7      181             84             21      192  35.9
# 245            9      184             85             15        0  30.0
# 283            7      161             86              0        0  30.4
# 323           13      152             90             33       29  26.8
# ...

# %%
locate.count()/locate1.count()
# Out:
# Pregnancies                 0.814815
# Glucose                     0.814815
# BloodPressure               0.814815
# SkinThickness               0.814815
# Insulin                     0.814815
# BMI                         0.814815
# DiabetesPedigreeFunction    0.814815
# Age                         0.814815
# Outcome                     0.814815
# Weight                      0.814815
# Age_category                0.814815
# dtype: float64

# %% [markdown]
# There is a 81.48% changce that Chenoa has diabetes.
