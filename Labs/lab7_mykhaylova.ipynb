# %%
# Together with all the necessary packages, use the following code to upload the us crime data set.
import pandas as pd
# Please note that this is a text data set not a csv file.
uc = pd.read_csv('uscrime.txt', delimiter ='\t')

# %% [markdown]
# More details about the data is here. http://www.statsci.org/data/general/uscrime.html

# %% [markdown]
# # Problem 1 [20]
# This data has 16 variables. Crime is the dependent variable. Starting with all 15 independent variables, find a multiple linear regression model that has only six significant variables ( p-value $<0.1$) while keeping $R^2\geq 75\%$. For this, you will have to remove one independent variable at a time from the original model, create a new model with the ramaining variables and stop when all the variables have $p$-value $<0.10$. Report the summary of the final model together with the coefficents. Comment on the final model.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
uc = pd.read_csv('uscrime.txt', delimiter ='\t')

# %%
uc.columns
# Out:
# Index(['M', 'So', 'Ed', 'Po1', 'Po2', 'LF', 'M.F', 'Pop', 'NW', 'U1', 'U2',
#        'Wealth', 'Ineq', 'Prob', 'Time', 'Crime'],
#       dtype='object')

# %%
y = uc['Crime']
x = uc[['M', 'So', 'Ed', 'Po1', 'Po2', 'LF', 'M.F', 'Pop', 'NW', 'U1', 'U2',
       'Wealth', 'Ineq', 'Prob', 'Time']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                     8.429
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           3.54e-07
# Time:                        15:54:39   Log-Likelihood:                -308.01
# No. Observations:                  47   AIC:                             648.0
# Df Residuals:                      31   BIC:                             677.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5984.2876   1628.318     -3.675      0.001   -9305.265   -2663.310
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'Po2', 'LF', 'M.F', 'Pop', 'NW', 'U1', 'U2',
       'Wealth', 'Ineq', 'Prob', 'Time']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     9.322
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           1.12e-07
# Time:                        15:55:49   Log-Likelihood:                -308.02
# No. Observations:                  47   AIC:                             646.0
# Df Residuals:                      32   BIC:                             673.8
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5980.6789   1596.659     -3.746      0.001   -9232.967   -2728.391
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'Po2', 'LF', 'M.F', 'Pop', 'NW', 'U1', 'U2',
       'Wealth', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     10.25
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           3.76e-08
# Time:                        15:56:22   Log-Likelihood:                -308.19
# No. Observations:                  47   AIC:                             644.4
# Df Residuals:                      33   BIC:                             670.3
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6285.4967   1455.742     -4.318      0.000   -9247.226   -3323.768
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'Po2', 'M.F', 'Pop', 'NW', 'U1', 'U2',
       'Wealth', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     11.34
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           1.21e-08
# Time:                        15:57:00   Log-Likelihood:                -308.37
# No. Observations:                  47   AIC:                             642.7
# Df Residuals:                      34   BIC:                             666.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6199.0822   1429.697     -4.336      0.000   -9104.577   -3293.587
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'Po2', 'M.F', 'Pop', 'U1', 'U2', 'Wealth', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     12.60
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           3.75e-09
# Time:                        15:57:33   Log-Likelihood:                -308.57
# No. Observations:                  47   AIC:                             641.1
# Df Residuals:                      35   BIC:                             663.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6222.9676   1414.406     -4.400      0.000   -9094.365   -3351.570
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'M.F', 'Pop', 'U1', 'U2', 'Wealth', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     14.04
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           1.17e-09
# Time:                        15:58:05   Log-Likelihood:                -308.85
# No. Observations:                  47   AIC:                             639.7
# Df Residuals:                      36   BIC:                             660.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6403.9840   1375.459     -4.656      0.000   -9193.545   -3614.424
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'M.F', 'Pop', 'U1', 'U2', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     15.58
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           4.17e-10
# Time:                        15:58:44   Log-Likelihood:                -309.39
# No. Observations:                  47   AIC:                             638.8
# Df Residuals:                      37   BIC:                             657.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6068.1757   1321.624     -4.591      0.000   -8746.041   -3390.311
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'M.F', 'U1', 'U2', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     17.74
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           1.16e-10
# Time:                        15:59:13   Log-Likelihood:                -309.66
# No. Observations:                  47   AIC:                             637.3
# Df Residuals:                      38   BIC:                             654.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6426.1010   1194.611     -5.379      0.000   -8844.464   -4007.738
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'U1', 'U2', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     19.06
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           8.81e-11
# Time:                        15:59:41   Log-Likelihood:                -311.27
# No. Observations:                  47   AIC:                             638.5
# Df Residuals:                      39   BIC:                             653.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5095.5521    896.895     -5.681      0.000   -6909.694   -3281.410
# ...

# %%
x = uc[['M', 'Ed', 'Po1', 'U2', 'Ineq', 'Prob']]
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     21.81
# Date:                Thu, 14 Oct 2021   Prob (F-statistic):           3.42e-11
# Time:                        16:00:05   Log-Likelihood:                -312.08
# No. Observations:                  47   AIC:                             638.2
# Df Residuals:                      40   BIC:                             651.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5040.5050    899.843     -5.602      0.000   -6859.156   -3221.854
# ...

# %% [markdown]
# R^2 is 0.766, the coefficients are: M = 105.0196, Ed = 196.4712, Po1 = 115.0242, U2 = 89.3660, Ineq = 67.6532, and Prob = -3801.8363. All of the variables have p-value of 0.0 or close to 0.0.

# %% [markdown]
# # Problem 2  [15]
# Filter the uc data with only the columns you found in the final model of problem 1 and the Crime column. Now split the data to testing and training following 75%, 25% rule. Use only the training data to fit the linear model.  Report the $R^2$ and adjusted $R^2$ for the training data. How do these compare with the $R^2$ and adjusted $R^2$ of the final model from problem 1? Explain why there is a difference in these numbers if any.

# %%
from sklearn.model_selection import train_test_split

# %%
xx = uc[['M', 'Ed', 'Po1', 'U2', 'Ineq', 'Prob']]
y = uc.Crime
xtrain, xtest, ytrain, ytest = model_selection.train_test_split(xx, y, test_size = 0.25, random_state = 17)

# %%
modelxx = sm.OLS(ytrain, sm.add_constant(xtrain)).fit()
modelxx.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Crime   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     16.77
# Date:                Fri, 15 Oct 2021   Prob (F-statistic):           4.10e-08
# Time:                        15:15:26   Log-Likelihood:                -233.94
# No. Observations:                  35   AIC:                             481.9
# Df Residuals:                      28   BIC:                             492.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5615.9991   1048.444     -5.357      0.000   -7763.640   -3468.358
# ...

# %% [markdown]
# The correlations of the training set R^2 (0.782) and the final model R^2 (0.766) are almost the same. This means that the relationship of the variables in the training set and the final model are very similar.
# The adjusted R^2 of the training set is 0.736 and in the final model is (0.731) are also almost the same. The relationship of the variables is similar.

# %% [markdown]
# # Problem 3 [15]
# Use the model from problem 2 to predict crime values using the testing data. Make a table of $R^2$. Adjusted-$R^2$, Root mean squared error (RMSE) and Mean Absolute Error (MAE) for the training and testing data sets. Compare and comment on all the numbers for training and testing data set.  Which of the 4 different measures is best for evaluating performance with testing and training?  Explain your reasoning.

# %%
ypred = modelxx.predict(sm.add_constant(xtest))
ypred
# Out:
# 46     990.269958
# 40     678.844983
# 16     476.449590
# 29     611.762732
# 21     790.782223
# 38     785.548024
# 41     333.651671
# 37     588.215765
# 43    1158.018446
# 33    1014.693705
# 35     933.659881
# 11     615.075454
# dtype: float64

# %%
from sklearn.metrics import r2_score
r2 = r2_score(ytest, ypred)
r2
# Out:
# 0.3103042882131918

# %%
adj = 1 - (1-r2_score(ytest, ypred)) * (len(y)-1)/(len(y)-x.shape[1]-1)
adj
# Out:
# 0.186512750200175

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse = sqrt(mean_squared_error(ytest, ypred))
rmse
# Out:
# 190.33082207861545

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ytest, ypred)
# Out:
# 158.66564688797703

# %%
ytrainpred = modelxx.predict(sm.add_constant(xtrain))
ytrainpred
# Out:
# 8      698.694184
# 24     634.644054
# 28    1498.369723
# 18    1154.301341
# 12     793.631566
# 2      426.865530
# 19    1204.261895
# 30     368.299403
# 23     927.542586
# 0      873.311455
# 26     178.861686
# 5      649.977343
# 13     734.414827
# 14     865.158114
# 36     906.857858
# 25    1824.225198
# 9      760.431497
# 42     976.441191
# 32     898.628737
# 27    1268.094049
# 45     727.784283
# 3     1917.422087
# 34     744.937073
# 10    1093.375114
# 17     826.881223
# 1     1392.967248
# 7     1420.128981
# 20     789.314530
# 39    1168.614659
# 4     1274.143210
# 31     753.838453
# 44     652.761917
# 22     965.161770
# 6      717.031588
# 15    1040.625628
# dtype: float64

# %%
r2 = r2_score(ytrain, ytrainpred)
r2
# Out:
# 0.7822672306364259

# %%
adj = 1 - (1-r2_score(ytrain, ytrainpred)) * (len(y)-1)/(len(y)-x.shape[1]-1)
adj
# Out:
# 0.7431869899814254

# %%
rmse = sqrt(mean_squared_error(ytrain, ytrainpred))
rmse
# Out:
# 193.44534410599067

# %%
mean_absolute_error(ytrain, ytrainpred)
# Out:
# 143.99068413562372

# %% [markdown]
# After finding values, you can click the following table and just fill in the values.
#
# |Measure | Training Data | Testing Data|
# |:-|:-:|-:|
# |**$R^2$**|$0.782$|$0.310$|
# |**Adjusted $R^2$**|$0.743$|$0.187$|
# |**RMSE**|$193.445$|$190.331$|
# |**MAE**|$143.991$|$158.666$|

# %% [markdown]
# The R^2 and the adjusted R^2 values are more highly positively correlated in the training data set than the testing data set. The errors for both sets are closely similar. R^2 is the best because higher value means more accurate representation of the data. It measures the difference between the observed data and the values, so higher r^2 means smaller margin of error.
